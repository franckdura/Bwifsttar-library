# %% [markdown]
# # **STAGE PONTS INSTRUMENTES - Notebook Spécial 4**

# %% [markdown]
# ## Table of Contents
#
# ### 0. [Bibliothèques](#0/-Bibliothèques)
# ### I. [Contraintes sur les vitesses dans les ensembles](#I/-Contraintes-sur-les-vitesses-dans-les-ensembles)
# ### II. [Création des sous ensembles](#II/-Création-des-sous-ensembles)
# ### III. [Calcul de la LI](#III/-Calcul-de-la-LI)
# ### IV. [Calcul des poids](#IV/-Calcul-des-poids)
#
# ### V. [Metrics](#V/-Metrics)
#
# ### VI. [Procédure](#VI/-Procédure)
#
# ### VII. [Tests](#VII/-Tests)

# %% [markdown]
# **Dans ce Notebook, nous allons implémenter une première procédure pour obtenir des statistiques sur toutes nos méthodes précédentes. Nous nous concentrerons surtout sur les fonctions et différentes façon de procéder. Les vrais résultats seront sur le Notebook N15**

# %% [markdown]
# ## 0/ Bibliothèques

# %%
from Bwifsttar import load_senlis_modified

# %% [markdown]
# ## I/ Contraintes sur les vitesses dans les ensembles

# %%
calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]

traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]

ensemble_trucks = []
se_LI = []
se_Poids = []

for i in range(0,len(calibration_trucks)):
    ensemble_trucks.append(calibration_trucks[i])
for j in range(0,len(traffic_trucks)):
    ensemble_trucks.append(traffic_trucks[j])

s70 = 0
for truck in ensemble_trucks:
    if truck.speed>23.6:
        s70+=1
        
    print(truck.speed)
print(s70)
def has_70(ensemble_trucks):
    for truck in ensemble_trucks:
        compteur = 0
        if truck.speed>23.8:
            compteur+=1
    if compteur<1:
        print("Pas ok 70")
        return False
    else:
        print("Ok 70")
        return True
    
def has_80(ensemble_trucks):
    for truck in ensemble_trucks:
        compteur = 0
        if truck.speed < 22.5:
            compteur+=1
    if compteur<1:
        print(compteur)
        print("Pas ok 80")

        return False
    else:
        print("Ok 80")
        return True

def has_90(ensemble_trucks):
    for truck in ensemble_trucks:
        compteur = 0
        if truck.speed>23:
            compteur+=1
    if compteur<1:
        print("Pas ok 90")
        return False
    else:
        print("Ok 90")
        return True
# Out:
# 18.96294211024312
# 24.00002912772182
# 18.963018634210332
# 21.63376871440886
# 24.380991984594182
# 18.50599705565925
# 23.272699098967962
# 18.731689060807692
# 23.630778718660313
# 21.333341568157582
# 23.630769230769232
# 23.630778718660313
# 24.0
# 23.99998055697778
# 24.380962370591252
# 23.27274641740299
# 25.18025490149026
# 22.26084595150235
# 23.63081643339881
# 22.260903648897617
# 23.630750086870428
# 23.272717998418727
# 24.000047940170667
# 24.00002912772182
# 24.380892824572964
# 14

# %%
calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
ensemble_trucks = []
se_LI = []
se_Poids = []

for i in range(0,len(calibration_trucks)):
    ensemble_trucks.append(calibration_trucks[i])
for j in range(0,len(traffic_trucks)):
    ensemble_trucks.append(traffic_trucks[j])

trucks70=[]
for i,j in enumerate(ensemble_trucks):
    if (j.speed<19):
        trucks70.append(ensemble_trucks[i])
        
trucks80=[]
for i,j in enumerate(ensemble_trucks):
    if (j.speed>=19 and j.speed<22):
        trucks80.append(ensemble_trucks[i])

trucks90=[]
for i,j in enumerate(ensemble_trucks):
    if (j.speed>=22 and j.speed<24):
        trucks90.append(ensemble_trucks[i])
        
trucks100 = []
for i,j in enumerate(ensemble_trucks):
    if (j.speed>=24):
        trucks100.append(ensemble_trucks[i])
        
print(len(trucks70))
print(len(trucks80))
print(len(trucks90))
print(len(trucks100))
repartition = 20
p70 = len(trucks70)/len(ensemble_trucks)
p80 = len(trucks80)/len(ensemble_trucks)
p90 = len(trucks90)/len(ensemble_trucks)
p100 = len(trucks100)/len(ensemble_trucks)
print("\n")
print(round(p70*repartition))
print(round(p80*repartition))
print(round(p90*repartition))
print(round(p100*repartition))
print("\n")
se_LI = []

idx70= np.arange(0,len(trucks70))
np.random.shuffle(idx70)
idx80= np.arange(0,len(trucks80))
np.random.shuffle(idx80)
idx90= np.arange(0,len(trucks90))
np.random.shuffle(idx90)
idx100= np.arange(0,len(trucks100))
np.random.shuffle(idx100)



for k in idx70[:round(p70*repartition)]:
    se_LI.append(trucks70[k])
for k in idx80[:round(p80*repartition)]:
    se_LI.append(trucks80[k])
for k in idx90[:round(p90*repartition)]:
    se_LI.append(trucks90[k])
for k in idx100[:round(p100*repartition)]:
    se_LI.append(trucks100[k])

print(len(se_LI))

for i,truck in enumerate(trucks70):
    if truck not in se_LI:
        se_Poids.append(trucks70[i])

for i,truck in enumerate(trucks80):
    if truck not in se_LI:
        se_Poids.append(trucks80[i])

for i,truck in enumerate(trucks90):
    if truck not in se_LI:
        se_Poids.append(trucks90[i])

for i,truck in enumerate(trucks100):
    if truck not in se_LI:
        se_Poids.append(trucks100[i])
print(len(se_Poids))
# Out:
# 4
# 2
# 11
# 8
#
#
# 3
# 2
# 9
# 6
#
#
# 20
# 5

# %% [markdown]
# ## II/ Création des sous ensembles

# %%
def get_SE2(repartition):
    calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
    calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
    traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
    traffic_trucks = [truck for i,truck in enumerate(traffic_trucksffic_trucks) if i!=3]
    ensemble_trucks = []
    se_LI = []
    se_Poids = []
    for i in range(0,len(calibration_trucks)):
        ensemble_trucks.append(calibration_trucks[i])
    for j in range(0,len(traffic_trucks)):
        ensemble_trucks.append(traffic_trucks[j])

    trucks70=[]
    for i,j in enumerate(ensemble_trucks):
        if (j.speed<19):
            trucks70.append(ensemble_trucks[i])

    trucks80=[]
    for i,j in enumerate(ensemble_trucks):
        if (j.speed>=19 and j.speed<22):
            trucks80.append(ensemble_trucks[i])

    trucks90=[]
    for i,j in enumerate(ensemble_trucks):
        if (j.speed>=22 and j.speed<24):
            trucks90.append(ensemble_trucks[i])

    trucks100 = []
    for i,j in enumerate(ensemble_trucks):
        if (j.speed>=24):
            trucks100.append(ensemble_trucks[i])
    bol = False
    while(not bol):
        p70 = len(trucks70)/len(ensemble_trucks)
        p80 = len(trucks80)/len(ensemble_trucks)
        p90 = len(trucks90)/len(ensemble_trucks)
        p100 = len(trucks100)/len(ensemble_trucks)
        if(round(p70*repartition)+round(p80*repartition)+round(p90*repartition)+round(p100*repartition)==repartition):
            bol=True

        
    idx70= np.arange(0,len(trucks70))
    np.random.shuffle(idx70)
    idx80= np.arange(0,len(trucks80))
    np.random.shuffle(idx80)
    idx90= np.arange(0,len(trucks90))
    np.random.shuffle(idx90)
    idx100= np.arange(0,len(trucks100))
    np.random.shuffle(idx100)
    for k in idx70[:round(p70*repartition)]:
        se_LI.append(trucks70[k])
    for k in idx80[:round(p80*repartition)]:
        se_LI.append(trucks80[k])
    for k in idx90[:round(p90*repartition)]:
        se_LI.append(trucks90[k])
    for k in idx100[:round(p100*repartition)]:
        se_LI.append(trucks100[k])
    for i,truck in enumerate(trucks70):
        if truck not in se_LI:
            se_Poids.append(trucks70[i])

    for i,truck in enumerate(trucks80):
        if truck not in se_LI:
            se_Poids.append(trucks80[i])

    for i,truck in enumerate(trucks90):
        if truck not in se_LI:
            se_Poids.append(trucks90[i])

    for i,truck in enumerate(trucks100):
        if truck not in se_LI:
            se_Poids.append(trucks100[i])
    return se_LI,se_Poids

# %%
def get_SE3(repartition):
    #repartition en %
    pcalib_LI=0.8
    ptraffic_LI = 0.2
    
    repartition = 0.01*repartition
    calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
    calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
    traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
    traffic_trucks = [truck for i,truck in enumerate(traffic_trucksffic_trucks) if i!=3]

    se_LI = []
    se_Poids = []
    n_total = len(calibration_trucks) + len(traffic_trucks)

    n_LI = round(repartition * n_total)
    
    n_calib_LI = round(pcalib_LI*n_LI)
    n_traffic_LI = round(ptraffic_LI*n_LI)
    
    
    
    
    idx_calib_LI = np.arange(0,len(calibration_trucks))
    np.random.shuffle(idx_calib_LI)
    idx_traffic_LI = np.arange(0,len(traffic_trucks))
    np.random.shuffle(idx_traffic_LI)

    
    trucks_calib_LI = []
    try:
        for i in range(n_calib_LI):
            trucks_calib_LI.append(calibration_trucks[idx_calib_LI[i]])
    except:
        trucks_calib_LI = calibration_trucks
        n_traffic_LI = n_LI-len(calibration_trucks)
        
        
    trucks_traffic_LI = []
    for i in range(n_traffic_LI):
        trucks_traffic_LI.append(traffic_trucks[idx_traffic_LI[i]])
        
        
        
        
    trucks_calib_Poids = []
    for i,truck in enumerate(calibration_trucks):
        if truck not in trucks_calib_LI:
            trucks_calib_Poids.append(calibration_trucks[i])
            
    trucks_traffic_Poids = []
    for i,truck in enumerate(traffic_trucks):
        if truck not in trucks_traffic_LI:
            trucks_traffic_Poids.append(traffic_trucks[i])
            
    for i in range(0,len(trucks_calib_LI)):
        se_LI.append(trucks_calib_LI[i])
        
    for i in range(0,len(trucks_traffic_LI)):
        se_LI.append(trucks_traffic_LI[i])
        
    for j in range(0,len(trucks_traffic_Poids)):
        se_Poids.append(trucks_traffic_Poids[j])
        
    for j in range(0,len(trucks_calib_Poids)):
        se_Poids.append(trucks_calib_Poids[j])
                                                                    
    
    return se_LI,se_Poids

# %%
# %matplotlib notebook
def get_SE(repartition):
    
    """
        ***** Get Sous Ensemble *****
        Retourne les deux sous ensembles aléatoirement choisis
        Repartition /30 camions
        
    """
    print("********** Working on SEs... **********")
    
    bol = False
    while(not bol):
        calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
        calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
        traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
        ensemble_trucks = []
        se_LI = []
        se_Poids = []

        for i in range(0,len(calibration_trucks)):
            ensemble_trucks.append(calibration_trucks[i])
        for j in range(0,len(traffic_trucks)):
            ensemble_trucks.append(traffic_trucks[j])

        n = len(ensemble_trucks)
        idx= np.arange(0,len(ensemble_trucks))
        np.random.shuffle(idx)
        #print(idx)
        for k in idx[:repartition]:
            se_LI.append(ensemble_trucks[k])
        for k in idx[repartition:]:
            se_Poids.append(ensemble_trucks[k])

        #se_LI = random.choices(ensemble_trucks, k=repartition)
        #print(len(se_LI))
        #se_Poids = [truck for truck in ensemble_trucks if truck not in se_LI]
        print(len(se_LI))
        if has_80(se_LI) and has_90(se_LI):
            bol = True
    return se_LI,se_Poids

# %% [markdown]
# ## III/ Calcul de la LI

# %%
def get_LI(se_LI):
    """
        Prend en paramètre le sous ensemble de camions pour interpoler la LI /vitesses
        Retourne la fonction interpolée
    """
    print("********** Working on LI... **********")
    list_speeds = []
    list_infl = []
    for i,truck in enumerate(se_LI):
        list_speeds.append(se_LI[i].speed)
        infl = calibration_mt(se_LI[i:i+1],l2_reg={'strength': 1e3, 'cutoff': 0.01},tv_reg={'strength': 1e3, 'cutoff': 0.95})
        list_infl.append(infl)
        
    func1D   = interp1d(list_speeds, list_infl, fill_value="extrapolate",axis=0)#permet à partir de meters et infuence de trouver une approximation de influence = f(meters)
    return func1D
"""func = get_LI(se1)

plt.figure()
for i in range(18,25,1):
    plt.plot(func(i),label=str(i))
plt.legend()
plt.show()"""
# Out:
# 'func = get_LI(se1)\n\nplt.figure()\nfor i in range(18,25,1):\n    plt.plot(func(i),label=str(i))\nplt.legend()\nplt.show()'

# %% [markdown]
# ## IV/ Calcul des poids

# %%
def get_poids(se_Poids,func1D):
    """
    
        Prend comme paramètre le sous ensemble de poids et la fonction interp LI/Vitesses
        Retourne la liste des poids estimés pour ces camions
    """
    print("********** Working on weights... **********")
    list_poids = []
    for i,truck in enumerate(se_Poids):
        #print(str(i+1)+"/"+str(len(se_Poids)))
        #decalage  = find_best_position_signal(truck,2,func1D)
        decalage = find_best_peaks(truck,2,func1D)
        #decalage = truck.peaks
        w = estimation_peaks(truck,decalage, func1D(truck.speed))
        list_poids.append(w)
    list_poids = np.array(list_poids)
    return list_poids

#poids = get_poids(se2,func)
#print(poids)

# %% [markdown]
# ## V/ Metrics

# %%
def get_erreur_essieu(se2,list_poids_estimes):
    print("********** Working on errors... **********")
    list_erreurs_essieu = []
    list_erreurs_totales = []
    for i,truck in enumerate(se2):
        poids_reel = truck.weights
        poids_total_reel= np.sum(truck.weights)
        poids_estime = list_poids_estimes[i]
        poids_total_estime = np.sum(list_poids_estimes[i])
        diff = abs(poids_reel-poids_estime)
        diff_totale = abs(poids_total_reel-poids_total_estime)
        list_erreurs_essieu.append(diff)
        list_erreurs_totales.append(diff_totale)
    list_erreurs_essieu = np.array(list_erreurs_essieu)
    list_erreurs_totales = np.array(list_erreurs_totales)
    return list_erreurs_essieu,list_erreurs_totales
"""
scores,scores_totaux = get_erreur_essieu(se2,poids)
print("Scores par essieu (t) \n", scores)
for j,i in enumerate(scores):
    print("\nScore Essieu (t) "+str(j),scores.T[j])
    print("Score moyen sur l'essieu (t) "+str(j),np.sum(scores.T[j])/len(scores.T[j]))
print("\nScores totaux (t) : ",scores_totaux)
print("\nScore total moyen (t) :",np.sum(scores_totaux)/len(scores_totaux))"""
# Out:
# '\nscores,scores_totaux = get_erreur_essieu(se2,poids)\nprint("Scores par essieu (t) \n", scores)\nfor j,i in enumerate(scores):\n    print("\nScore Essieu (t) "+str(j),scores.T[j])\n    print("Score moyen sur l\'essieu (t) "+str(j),np.sum(scores.T[j])/len(scores.T[j]))\nprint("\nScores totaux (t) : ",scores_totaux)\nprint("\nScore total moyen (t) :",np.sum(scores_totaux)/len(scores_totaux))'

# %%
def get_metrics(list_erreurs_essieu,list_erreurs_totales,se2):
    print("**********  Working on metrics... **********")
    """
        Prend en params les erreurs sur essieux et les erreurs totales
        
        Retourne :
        - l'erreur total moyenne sur l'ensemble des camions de test, ok
        - la liste des % d'erreur sur le poids total de chaque camion de test ok
        - le % d'erreur moyen sur les poids totaux des camions de test, ok
        - la liste des erreurs moyennes par essieu, ok
        - la liste des % d'erreur moyen par essieu, ok
    """
    poids_totaux = []
    poids = []
    for truck in se2:
        poids_totaux.append(np.sum(truck.weights))
        poids.append(truck.weights)
    poids = np.array(poids)
    poids_essieu_moyen = []
    for poid in poids.T:
        poids_essieu_moyen.append(np.sum(poid)/len(poid))
        
        
    scores_moyen_essieux = []
    percent_moyen_essieux = []
    score_moyen_total = np.sum(list_erreurs_totales)/len(list_erreurs_totales)
    percent_erreur_totale = []
    
    for j,i in enumerate(list_erreurs_essieu.T):
        scores_moyen_essieux.append(np.sum(i)/len(i))
    
    for j,i in enumerate(poids_essieu_moyen):
        val = 1 - (poids_essieu_moyen[j]-scores_moyen_essieux[j])/poids_essieu_moyen[j]
        percent_moyen_essieux.append(val)
    
    for j,i in enumerate(poids_totaux):
        val = 1 - (poids_totaux[j]-list_erreurs_totales[j])/poids_totaux[j]
        percent_erreur_totale.append(val)
    
    percent_erreur_totale_moy = np.sum(percent_erreur_totale)/len(percent_erreur_totale)
    
    return np.array(score_moyen_total),np.array([percent_erreur_totale])*100,np.array([percent_erreur_totale_moy])*100,np.array(scores_moyen_essieux),100*np.array(percent_moyen_essieux)

#erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)

# %%
"""print("\n\n\n\nMetrics sur les poids totaux : \n\n")
print("Liste des erreurs totales (t) : ",scores_totaux)
print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)

print("\n\nMetrics sur les poids par essieu : \n\n")
print("Scores par essieu (t) \n", scores)
print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)"""
# Out:
# 'print("\n\n\n\nMetrics sur les poids totaux : \n\n")\nprint("Liste des erreurs totales (t) : ",scores_totaux)\nprint("\nErreur totale moyenne sur l\'ensemble des camions de test (t) : ",erreur_tot_moy)\nprint("\nListe des % d\'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)\nprint("\n% d\'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)\n\nprint("\n\nMetrics sur les poids par essieu : \n\n")\nprint("Scores par essieu (t) \n", scores)\nprint("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)\nprint("\nListe des % d\'erreur moyen par essieu (%) : ",list_percent_moy_essieux)'

# %% [markdown]
# ## VI/ Procédure

# %%
import matplotlib.pyplot as plt
import collections 
import numpy as np
def get_stats(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    for i in range(iterations):
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE(repartition)
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))
            list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))

            list_percent_tot.append(100*(list_erreurs_tot_redr[a]/np.sum(se2[a].weights)))
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            for a,j in enumerate(poids_estimes.T[0]):
                list_erreur_essieu1.append(j-se2[a].weights[0])
            for a,j in enumerate(poids_estimes.T[1]):
                list_erreur_essieu2.append(j-se2[a].weights[1])
            for a,j in enumerate(poids_estimes.T[2]):
                list_erreur_essieu3.append(j-se2[a].weights[2])
            for a,j in enumerate(poids_estimes.T[3]):
                list_erreur_essieu4.append(j-se2[a].weights[3])
            for a,j in enumerate(poids_estimes.T[4]):
                list_erreur_essieu5.append(j-se2[a].weights[4])
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
    
    erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
    erreur_essieu_moy =list_erreur_essieu_moy/iterations
    percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/iterations
    percent_erreur_essieux = list_percent_erreur_essieu/iterations
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    unique, counts = np.unique(list_erreurs_tot, return_counts=True)

    unique2, counts2 = np.unique(list_percent_tot, return_counts=True)
    unique3, counts3 = np.unique(list_erreurs_tot_redr, return_counts=True)
    unique4,count4 = np.unique(list_erreur_essieu1, return_counts=True)
    unique5,count5 = np.unique(list_erreur_essieu2, return_counts=True)
    unique6,count6 = np.unique(list_erreur_essieu3, return_counts=True)
    unique7,count7 = np.unique(list_erreur_essieu4, return_counts=True)
    unique8,count8 = np.unique(list_erreur_essieu5, return_counts=True)

    width = 0.05
    print(dict(zip(unique, counts)))
    plt.figure()
    plt.bar(unique,counts,0.005)
    plt.title("Erreurs sur les poids totaux (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique3,counts3,0.01)
    plt.title("Erreurs sur les poids totaux redressés (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique2,counts2,width)
    plt.title("% Erreurs sur les poids totaux (%)")
    plt.show()

    plt.figure()
    plt.bar(unique4,count4,0.005)
    plt.title("Erreurs sur l'essieu 1 (t)")
    plt.show()

    plt.figure()
    plt.bar(unique5,count5,0.005)
    plt.title("Erreurs sur l'essieu 2 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique6,count6,0.005)
    plt.title("Erreurs sur l'essieu 3 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique7,count7,0.005)
    plt.title("Erreurs sur l'essieu 4 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique8,count8,0.005)
    plt.title("Erreurs sur l'essieu 5 (t)")
    plt.show()
    
    variance_poids_tot = np.var(list_erreurs_tot)
    print("Variance sur les poids totaux: ",variance_poids_tot)
    return erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(2,20)
# Out:
# Itération n° : 1/2
# ********** Working on SEs... **********
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# 0
# Pas ok 80
# 20
# Ok 80
# Pas ok 90
# 20
# 0
# Pas ok 80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4e73400d5fb6> in <module>
#     132     print("Variance sur les poids totaux: ",variance_poids_tot)
#     133     return erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
# --> 134 erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(2,20)
#
# <ipython-input-14-4e73400d5fb6> in get_stats(iterations, repartition)
#      30     for i in range(iterations):
#      31         print("Itération n° : "+str(i+1)+"/"+str(iterations))
# ---> 32         se1,se2 = get_SE(repartition)
#      33         func = get_LI(se1)
#      34         poids_estimes = get_poids(se2,func)
#
# <ipython-input-5-748c318d81df> in get_SE(repartition)
#      12     bol = False
#      13     while(not bol):
# ---> 14         calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
#      15         calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
#      16         traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
#
# ~/Documents/Stage_ponts_instrumentes/master/workspace/Bwifsttar/loadmt.py in load_senlis_modified(selected)
#     115     senlis_weights_modified = get_senlis_weights_modified()
#     116     traffic_trucks = extract_data('data/senlis/trafic/', 0, [1,2], selected, senlis_weights_modified)
# --> 117     calibration_trucks = extract_data('data/senlis/calibration/', 0, [1,2], selected, senlis_weights_modified)
#     118
#     119     return calibration_trucks,traffic_trucks
#
# ~/Documents/Stage_ponts_instrumentes/master/workspace/Bwifsttar/loadmt.py in extract_data(root_path, time_idx, speed_idx, signal_idx, static_weights)
#      95     trucks = []
#      96     for name in files:
# ---> 97         events  = read_file(name)
#      98         name    = name.stem
#      99         weights = static_weights[name] if static_weights is not None else None
#
# ~/Documents/Stage_ponts_instrumentes/master/workspace/Bwifsttar/loadmt.py in read_file(name)
#      87         for line in f:
#      88             data.append(line.split())
# ---> 89     data = np.array(data, dtype=float).T  # matrix of shape (n_signals, n_samples)
#      90     return data
#      91
#
# KeyboardInterrupt:

# %%
print(str(erreur_tot_moy)+" - Erreur totale moyenne (t)\n" )
print(str(erreur_essieu_moy)+" - Erreur par essieu moyenne (t)\n")
print(str(percent_err_tot_moy)+" - Pourcentage erreur totale moyen (%)\n")
print(str(percent_erreur_essieux)+" - Pourcentage erreur par essieu (%)\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7de042857ef1> in <module>
# ----> 1 print(str(erreur_tot_moy)+" - Erreur totale moyenne (t)\n" )
#       2 print(str(erreur_essieu_moy)+" - Erreur par essieu moyenne (t)\n")
#       3 print(str(percent_err_tot_moy)+" - Pourcentage erreur totale moyen (%)\n")
#       4 print(str(percent_erreur_essieux)+" - Pourcentage erreur par essieu (%)\n")
#
# NameError: name 'erreur_tot_moy' is not defined

# %% [markdown]
# ## VII/ Tests

# %%
#il faut : 
#   - Liste erreurs poids totaux

# %%
import matplotlib.pyplot as plt
import collections 

def get_stats(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    for i in range(iterations):
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE(repartition)
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))
            list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))

            list_percent_tot.append(100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            for a,j in enumerate(poids_estimes.T[0]):
                list_erreur_essieu1.append(j-se2[a].weights[0])
            for a,j in enumerate(poids_estimes.T[1]):
                list_erreur_essieu2.append(j-se2[a].weights[1])
            for a,j in enumerate(poids_estimes.T[2]):
                list_erreur_essieu3.append(j-se2[a].weights[2])
            for a,j in enumerate(poids_estimes.T[3]):
                list_erreur_essieu4.append(j-se2[a].weights[3])
            for a,j in enumerate(poids_estimes.T[4]):
                list_erreur_essieu5.append(j-se2[a].weights[4])
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
    
    erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
    erreur_essieu_moy =list_erreur_essieu_moy/iterations
    percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/iterations
    percent_erreur_essieux = list_percent_erreur_essieu/iterations
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    unique, counts = np.unique(list_erreurs_tot, return_counts=True)

    unique2, counts2 = np.unique(list_percent_tot, return_counts=True)
    unique3, counts3 = np.unique(list_erreurs_tot_redr, return_counts=True)
    unique4,count4 = np.unique(list_erreur_essieu1, return_counts=True)
    unique5,count5 = np.unique(list_erreur_essieu2, return_counts=True)
    unique6,count6 = np.unique(list_erreur_essieu3, return_counts=True)
    unique7,count7 = np.unique(list_erreur_essieu4, return_counts=True)
    unique8,count8 = np.unique(list_erreur_essieu5, return_counts=True)

    width = 0.05
    print(dict(zip(unique, counts)))
    plt.figure()
    plt.bar(unique,counts,0.005)
    plt.title("Erreurs sur les poids totaux (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique3,counts3,0.01)
    plt.title("Erreurs sur les poids totaux redressés (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique2,counts2,width)
    plt.title("% Erreurs sur les poids totaux (%)")
    plt.show()

    plt.figure()
    plt.bar(unique4,count4,0.005)
    plt.title("Erreurs sur l'essieu 1 (t)")
    plt.show()

    plt.figure()
    plt.bar(unique5,count5,0.005)
    plt.title("Erreurs sur l'essieu 2 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique6,count6,0.005)
    plt.title("Erreurs sur l'essieu 3 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique7,count7,0.005)
    plt.title("Erreurs sur l'essieu 4 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique8,count8,0.005)
    plt.title("Erreurs sur l'essieu 5 (t)")
    plt.show()
    
    variance_poids_tot = np.var(list_erreurs_tot)
    print("Variance sur les poids totaux: ",variance_poids_tot)
    return erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(5,20)
# Out:
# Itération n° : 1/5
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# Itération n° : 2/5
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# Itération n° : 3/5
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# Itération n° : 4/5
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# Itération n° : 5/5
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# {-3.794132882677502: 1, -2.6643968499251756: 1, -2.6425578326859522: 1, -0.039304517660752936: 1, 0.24125738719100553: 5, 0.34272085601553925: 1, 0.3467595814660882: 1, 0.42903000872387764: 1, 0.44920380661817916: 1, 0.5345637303725681: 1, 0.536176823996243: 1, 0.546010042846369: 1, 0.5478146753950099: 1, 1.189280831245057: 1, 1.5575093682925996: 1, 2.220085094988441: 1, 2.225679363583282: 1, 2.2274962770519124: 1, 2.5576832289247164: 1, 2.6102042619107166: 1, 3.416181147977639: 1}
# Variance sur les poids totaux:  2.6661848351766433

# %%
print(str(erreur_tot_moy)+" - Erreur totale moyenne (t)\n" )
print(str(erreur_essieu_moy)+" - Erreur par essieu moyenne (t)\n")
print(str(percent_err_tot_moy)+" - Pourcentage erreur totale moyen (%)\n")
print(str(percent_erreur_essieux)+" - Pourcentage erreur par essieu (%)\n")
# Out:
# 1.2833231247325059 - Erreur totale moyenne (t)
#
# [0.1853037  0.43302794 0.30547273 0.36179046 0.33760302] - Erreur par essieu moyenne (t)
#
# 3.1408877272415183 - Pourcentage erreur totale moyen (%)
#
# [2.62679123 3.80047474 3.49208845 4.72120745 4.39759443] - Pourcentage erreur par essieu (%)

# %%
calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]

# %%
for truck in traffic_trucks:
    plt.figure()
    plt.plot(truck.signals)

# %%
for truck in calibration_trucks:
    plt.figure()
    plt.plot(truck.signals)

# %%
import matplotlib.pyplot as plt
import collections 

def get_stats(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    for i in range(iterations):
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE(repartition)
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))
            list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))
            if list_erreurs_tot_redr[a]>10:
                truck_anormale = se2[a]
            else :
                truck_anormale = None
                
            list_percent_tot.append(100*(list_erreurs_tot_redr[a]/np.sum(se2[a].weights)))
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            for a,j in enumerate(poids_estimes.T[0]):
                list_erreur_essieu1.append(j-se2[a].weights[0])
            for a,j in enumerate(poids_estimes.T[1]):
                list_erreur_essieu2.append(j-se2[a].weights[1])
            for a,j in enumerate(poids_estimes.T[2]):
                list_erreur_essieu3.append(j-se2[a].weights[2])
            for a,j in enumerate(poids_estimes.T[3]):
                list_erreur_essieu4.append(j-se2[a].weights[3])
            for a,j in enumerate(poids_estimes.T[4]):
                list_erreur_essieu5.append(j-se2[a].weights[4])
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
    
    erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
    erreur_essieu_moy =list_erreur_essieu_moy/iterations
    percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/iterations
    percent_erreur_essieux = list_percent_erreur_essieu/iterations
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    unique, counts = np.unique(list_erreurs_tot, return_counts=True)

    unique2, counts2 = np.unique(list_percent_tot, return_counts=True)
    unique3, counts3 = np.unique(list_erreurs_tot_redr, return_counts=True)
    unique4,count4 = np.unique(list_erreur_essieu1, return_counts=True)
    unique5,count5 = np.unique(list_erreur_essieu2, return_counts=True)
    unique6,count6 = np.unique(list_erreur_essieu3, return_counts=True)
    unique7,count7 = np.unique(list_erreur_essieu4, return_counts=True)
    unique8,count8 = np.unique(list_erreur_essieu5, return_counts=True)

    width = 0.05
    print(dict(zip(unique, counts)))
    plt.figure()
    plt.bar(unique,counts,0.005)
    plt.title("Erreurs sur les poids totaux (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique3,counts3,0.01)
    plt.title("Erreurs sur les poids totaux redressés (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique2,counts2,width)
    plt.title("% Erreurs sur les poids totaux (%)")
    plt.show()

    plt.figure()
    plt.bar(unique4,count4,0.005)
    plt.title("Erreurs sur l'essieu 1 (t)")
    plt.show()

    plt.figure()
    plt.bar(unique5,count5,0.005)
    plt.title("Erreurs sur l'essieu 2 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique6,count6,0.005)
    plt.title("Erreurs sur l'essieu 3 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique7,count7,0.005)
    plt.title("Erreurs sur l'essieu 4 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique8,count8,0.005)
    plt.title("Erreurs sur l'essieu 5 (t)")
    plt.show()
    
    variance_poids_tot = np.var(list_erreurs_tot)
    print("Variance sur les poids totaux: ",variance_poids_tot)
    return truck_anormale,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
ta,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(3,10)
# Out:
# Itération n° : 1/3
# ********** Working on SEs... **********
# ********** Working on LI... **********
# ********** Working on weights... **********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-ddf1aebafa8b> in <module>
#     136     print("Variance sur les poids totaux: ",variance_poids_tot)
#     137     return truck_anormale,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
# --> 138 ta,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(3,10)
#
# <ipython-input-52-ddf1aebafa8b> in get_stats(iterations, repartition)
#      32         se1,se2 = get_SE(repartition)
#      33         func = get_LI(se1)
# ---> 34         poids_estimes = get_poids(se2,func)
#      35         scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
#      36         erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
#
# <ipython-input-13-fd444f95da1b> in get_poids(se_Poids, func1D)
#       9         #print(str(i+1)+"/"+str(len(se_Poids)))
#      10         #decalage  = find_best_position_signal(truck,2,func1D)
# ---> 11         decalage = find_best_peaks(truck,2,func1D)
#      12         #decalage = truck.peaks
#      13         w = estimation_peaks(truck,decalage, func1D(truck.speed))
#
# ~/Documents/Stage_ponts_instrumentes/master/workspace/interpolation_LI.py in find_best_peaks(truck, decalage, func1D)
#     579     param = ng.p.Instrumentation(ng.p.Choice(comb))
#     580     optimizer = ng.optimizers.DoubleFastGADiscreteOnePlusOne(parametrization=param, budget=100)
# --> 581     res_optimizer = np.array(optimizer.minimize(func_to_min).value[0][0])
#     582     res_min = eval_LI(influence,truck,truck.peaks)
#     583     if (eval_LI(influence,truck,res_optimizer) < res_min):
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/optimization/base.py in minimize(self, objective_function, executor, batch_mode, verbosity)
#     481                     print(f"Launching {new_sugg} jobs with new suggestions")
#     482                 for _ in range(new_sugg):
# --> 483                     args = self.ask()
#     484                     self._running_jobs.append((args, executor.submit(func, *args.args, **args.kwargs)))
#     485                 if new_sugg:
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/optimization/base.py in ask(self)
#     323                 candidate = self._suggestions.pop()
#     324             else:
# --> 325                 candidate = self._internal_ask_candidate()
#     326                 # only register actual asked points
#     327             if candidate.satisfies_constraints():
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/optimization/optimizerlib.py in _internal_ask_candidate(self)
#     118                 }[mutation]
#     119                 data = func(pessimistic_data)
# --> 120             return pessimistic.set_standardized_data(data, reference=ref)
#     121
#     122     def _internal_tell(self, x: ArrayLike, value: float) -> None:
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in set_standardized_data(self, data, reference, deterministic)
#     177         assert isinstance(sent_reference, self.__class__), f"Expected {type(self)} but got {type(sent_reference)} as reference"
#     178         self._check_frozen()
# --> 179         self._internal_set_standardized_data(np.array(data, copy=False), reference=sent_reference, deterministic=deterministic)
#     180         return self
#     181
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in _internal_set_standardized_data(self, data, reference, deterministic)
#     526         for name, size in self._sizes.items():
#     527             end = start + size
# --> 528             self._content[name].set_standardized_data(data[start: end], reference=reference[name], deterministic=deterministic)
#     529             start = end
#     530         assert end == len(data), f"Finished at {end} but expected {len(data)}"
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in set_standardized_data(self, data, reference, deterministic)
#     177         assert isinstance(sent_reference, self.__class__), f"Expected {type(self)} but got {type(sent_reference)} as reference"
#     178         self._check_frozen()
# --> 179         self._internal_set_standardized_data(np.array(data, copy=False), reference=sent_reference, deterministic=deterministic)
#     180         return self
#     181
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in _internal_set_standardized_data(self, data, reference, deterministic)
#     526         for name, size in self._sizes.items():
#     527             end = start + size
# --> 528             self._content[name].set_standardized_data(data[start: end], reference=reference[name], deterministic=deterministic)
#     529             start = end
#     530         assert end == len(data), f"Finished at {end} but expected {len(data)}"
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in set_standardized_data(self, data, reference, deterministic)
#     177         assert isinstance(sent_reference, self.__class__), f"Expected {type(self)} but got {type(sent_reference)} as reference"
#     178         self._check_frozen()
# --> 179         self._internal_set_standardized_data(np.array(data, copy=False), reference=sent_reference, deterministic=deterministic)
#     180         return self
#     181
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/choice.py in _internal_set_standardized_data(self, data, reference, deterministic)
#     209
#     210     def _internal_set_standardized_data(self: C, data: np.ndarray, reference: C, deterministic: bool = False) -> None:
# --> 211         super()._internal_set_standardized_data(data, reference=reference, deterministic=deterministic)
#     212         self._draw(deterministic=deterministic)
#     213
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in _internal_set_standardized_data(self, data, reference, deterministic)
#     526         for name, size in self._sizes.items():
#     527             end = start + size
# --> 528             self._content[name].set_standardized_data(data[start: end], reference=reference[name], deterministic=deterministic)
#     529             start = end
#     530         assert end == len(data), f"Finished at {end} but expected {len(data)}"
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in set_standardized_data(self, data, reference, deterministic)
#     177         assert isinstance(sent_reference, self.__class__), f"Expected {type(self)} but got {type(sent_reference)} as reference"
#     178         self._check_frozen()
# --> 179         self._internal_set_standardized_data(np.array(data, copy=False), reference=sent_reference, deterministic=deterministic)
#     180         return self
#     181
#
# /usr/local/lib/python3.8/dist-packages/nevergrad/parametrization/core.py in _internal_set_standardized_data(self, data, reference, deterministic)
#     526         for name, size in self._sizes.items():
#     527             end = start + size
# --> 528             self._content[name].set_standardized_data(data[start: end], reference=reference[name], deterministic=deterministic)
#     529             start = end
#     530         assert end == len(data), f"Finished at {end} but expected {len(data)}"
#
# KeyboardInterrupt:

# %%
ta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-adfa46750630> in <module>
# ----> 1 ta
#
# NameError: name 'ta' is not defined

# %%
print(str(erreur_tot_moy)+" - Erreur totale moyenne (t)\n" )
print(str(erreur_essieu_moy)+" - Erreur par essieu moyenne (t)\n")
print(str(percent_err_tot_moy)+" - Pourcentage erreur totale moyen (%)\n")
print(str(percent_erreur_essieux)+" - Pourcentage erreur par essieu (%)\n")
# Out:
# 2.501331425195054 - Erreur totale moyenne (t)
#
# [0.35215275 0.71938865 0.71293899 0.57693117 0.50735524] - Erreur par essieu moyenne (t)
#
# 6.163416918965949 - Pourcentage erreur totale moyen (%)
#
# [4.80978703 6.2505058  8.23181697 7.3966205  6.50056249] - Pourcentage erreur par essieu (%)

# %%
import matplotlib.pyplot as plt
import collections 

def get_stats(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    for i in range(iterations):
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE(repartition)
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))
            list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))

            list_percent_tot.append(100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            for a,j in enumerate(poids_estimes.T[0]):
                list_erreur_essieu1.append(j-se2[a].weights[0])
            for a,j in enumerate(poids_estimes.T[1]):
                list_erreur_essieu2.append(j-se2[a].weights[1])
            for a,j in enumerate(poids_estimes.T[2]):
                list_erreur_essieu3.append(j-se2[a].weights[2])
            for a,j in enumerate(poids_estimes.T[3]):
                list_erreur_essieu4.append(j-se2[a].weights[3])
            for a,j in enumerate(poids_estimes.T[4]):
                list_erreur_essieu5.append(j-se2[a].weights[4])
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
    
    erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
    erreur_essieu_moy =list_erreur_essieu_moy/iterations
    percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/iterations
    percent_erreur_essieux = list_percent_erreur_essieu/iterations
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    unique, counts = np.unique(list_erreurs_tot, return_counts=True)

    unique2, counts2 = np.unique(list_percent_tot, return_counts=True)
    unique3, counts3 = np.unique(list_erreurs_tot_redr, return_counts=True)
    unique4,count4 = np.unique(list_erreur_essieu1, return_counts=True)
    unique5,count5 = np.unique(list_erreur_essieu2, return_counts=True)
    unique6,count6 = np.unique(list_erreur_essieu3, return_counts=True)
    unique7,count7 = np.unique(list_erreur_essieu4, return_counts=True)
    unique8,count8 = np.unique(list_erreur_essieu5, return_counts=True)

    width = 0.05
    print(dict(zip(unique, counts)))
    plt.figure()
    plt.bar(unique,counts,0.005)
    plt.title("Erreurs sur les poids totaux (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique3,counts3,0.01)
    plt.title("Erreurs sur les poids totaux redressés (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique2,counts2,width)
    plt.title("% Erreurs sur les poids totaux (%)")
    plt.show()

    plt.figure()
    plt.bar(unique4,count4,0.005)
    plt.title("Erreurs sur l'essieu 1 (t)")
    plt.show()

    plt.figure()
    plt.bar(unique5,count5,0.005)
    plt.title("Erreurs sur l'essieu 2 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique6,count6,0.005)
    plt.title("Erreurs sur l'essieu 3 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique7,count7,0.005)
    plt.title("Erreurs sur l'essieu 4 (t)")
    plt.show()
    
    plt.figure()
    plt.bar(unique8,count8,0.005)
    plt.title("Erreurs sur l'essieu 5 (t)")
    plt.show()
    
    variance_poids_tot = np.var(list_erreurs_tot)
    print("Variance sur les poids totaux: ",variance_poids_tot)
    return unique5,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
u5,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(5,10)
# Out:
# Itération n° : 1/5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b457cf94c0ca> in <module>
#     132     print("Variance sur les poids totaux: ",variance_poids_tot)
#     133     return unique5,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux
# --> 134 u5,erreur_tot_moy,erreur_essieu_moy,percent_err_tot_moy,percent_erreur_essieux= get_stats(5,10)
#
# <ipython-input-32-b457cf94c0ca> in get_stats(iterations, repartition)
#      30     for i in range(iterations):
#      31         print("Itération n° : "+str(i+1)+"/"+str(iterations))
# ---> 32         se1,se2 = get_SE(repartition)
#      33         func = get_LI(se1)
#      34         poids_estimes = get_poids(se2,func)
#
# NameError: name 'get_SE' is not defined

# %%
plt.figure()
plt.hist(u5)
plt.show()

# %%
import matplotlib.pyplot as plt
import collections 

def get_stats3(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    list_trucks_anormaux = []
    for i in range(iterations):
        
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE3(repartition)
        print("LEN SE1 : ",len(se1))
        print("LEN SE2 : ",len(se2))
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            print("ERREUR : ",np.sum(j)-np.sum(se2[a].weights))
            
            if(((np.sum(j)-np.sum(se2[a].weights)) > 20) or ((np.sum(j)-np.sum(se2[a].weights ))< -20)):
                list_trucks_anormaux.append(se2[a])
                print(se2[a].speed)
                plt.figure()
                plt.plot(se2[a].signals)
                plt.show()
                print(eval_LI(func(se2[a].speed),truck,truck.peaks))
                reconstructed, rescaled = reconstruction_peaks(se2[a], func(se2[a].speed),se2[a].peaks)
                meters = truck.speed*truck.time
                plt.plot(meters[:len(reconstructed)], reconstructed[:len(meters)], linewidth=2, label='Recon.')
                plt.plot(meters[:len(se2[a].signals.T)], se2[a].signals.T[:len(meters)], label='Observed', alpha=0.7)
                plt.legend()
                plt.show()
            else:
                try:
                    list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))

                    list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))

                    list_percent_tot.append(100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
                except:
                    continue
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
                try:
                    for a,j in enumerate(poids_estimes.T[0]):
                        try:
                            list_erreur_essieu1.append(j-se2[a].weights[0])
                        except:
                            continue
                    for a,j in enumerate(poids_estimes.T[1]):
                        try:
                            list_erreur_essieu2.append(j-se2[a].weights[1])
                        except:
                            continue

                    for a,j in enumerate(poids_estimes.T[2]):
                        try:
                            list_erreur_essieu3.append(j-se2[a].weights[2])
                        except:

                            continue
                    for a,j in enumerate(poids_estimes.T[3]):
                        try:
                            list_erreur_essieu4.append(j-se2[a].weights[3])
                        except:
                            continue
                    for a,j in enumerate(poids_estimes.T[4]):
                        try:
                            list_erreur_essieu5.append(j-se2[a].weights[4])
                        except:
                            continue
                except:
                    pass
                np.save("erreurs_tot.npy",list_erreurs_tot)
                np.save("erreurs_tot_redr.npy",list_erreurs_tot_redr)
                np.save("erreur_essieu1.npy",list_erreur_essieu1)
                np.save("erreur_essieu2.npy",list_erreur_essieu2)
                np.save("erreur_essieu3.npy",list_erreur_essieu3)
                np.save("erreur_essieu4.npy",list_erreur_essieu4)
                np.save("erreur_essieu5.npy",list_erreur_essieu5)
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        #list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        #list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
        
        #erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
        #erreur_essieu_moy =list_erreur_essieu_moy/len(list_erreur_essieu_moy)
        #percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/len(list_percent_erreur_moy_tot)
        #percent_erreur_essieux = list_percent_erreur_essieu/len(list_percent_erreur_essieu)
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    
    
    return list_trucks_anormaux,list_erreurs_tot,list_erreurs_tot_redr,list_percent_tot,list_erreur_essieu1,list_erreur_essieu2,list_erreur_essieu3,list_erreur_essieu4,list_erreur_essieu5
lta,let,letr,lpt,lee1,lee2,lee3,lee4,lee5= get_stats3(5,50
                                                 )
# Out:
# Itération n° : 1/5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-586bd9cb253d> in <module>
#     131
#     132     return list_trucks_anormaux,list_erreurs_tot,list_erreurs_tot_redr,list_percent_tot,list_erreur_essieu1,list_erreur_essieu2,list_erreur_essieu3,list_erreur_essieu4,list_erreur_essieu5
# --> 133 lta,let,letr,lpt,lee1,lee2,lee3,lee4,lee5= get_stats3(5,50
#     134                                                  )
#
# <ipython-input-12-586bd9cb253d> in get_stats3(iterations, repartition)
#      32
#      33         print("Itération n° : "+str(i+1)+"/"+str(iterations))
# ---> 34         se1,se2 = get_SE3(repartition)
#      35         print("LEN SE1 : ",len(se1))
#      36         print("LEN SE2 : ",len(se2))
#
# <ipython-input-5-bcfc3188084e> in get_SE3(repartition)
#       8     calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
#       9     traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
# ---> 10     traffic_trucks = [truck for i,truck in enumerate(traffic_trucksffic_trucks) if i!=3]
#      11
#      12     se_LI = []
#
# NameError: name 'traffic_trucksffic_trucks' is not defined

# %%
for i,truck in enumerate(lta):
    plt.figure()
    plt.plot(truck.signals,label=str(lta[i].speed))
    plt.legend()
plt.show()
calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
calibration_trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]

for truck in calibration_trucks:
    for t in lta:
        if (t.speed == truck.speed):
            print("truck calib trouvé")

for truck in traffic_trucks:
    for t in lta:
        if (t.speed == truck.speed):
            print("truck calib trouvé")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# truck calib trouvé
# truck calib trouvé
# truck calib trouvé

# %%
import seaborn as sns
# %matplotlib inline

sns.distplot(let, hist=True, rug=True);
plt.title("Erreurs sur les poids totaux (t)")
# Out:
# Text(0.5, 1.0, 'Erreurs sur les poids totaux (t)')

# %%
# %matplotlib notebook
sns.distplot(let, hist=True, rug=True);
plt.title("Erreurs sur les poids totaux (t)")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
let2 = [l for l in let if abs(l)<20]

# %%
print(np.mean(let2))
print(np.std(let2))
# Out:
# 0.87209170476065
# 3.8570449671394837

# %%
print(np.mean(let))
print(np.std(let))
# Out:
# 1.4478351401274074
# 9.001905128331265

# %%
# %matplotlib notebook

sns.distplot(letr, hist=True, rug=True);
plt.title("Erreurs sur les poids totaux redressés (t)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sns.distplot(lpt, hist=True, rug=True);
plt.title("Erreurs sur les poids totaux (%)")
# Out:
# Text(0.5, 1.0, 'Erreurs sur les poids totaux (%)')

# %%
plt.figure()
sns.distplot(lee1, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 1 (t)")
plt.figure()
sns.distplot(lee2, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 2 (t)")
plt.figure()
sns.distplot(lee3, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 3 (t)")
plt.figure()
sns.distplot(lee4, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 4 (t)")
plt.figure()
sns.distplot(lee5, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 5 (t)")
# Out:
# Text(0.5, 1.0, 'Erreurs sur les poids Essieu 5 (t)')

# %%
import matplotlib.pyplot as plt
import collections 

def get_stats2(iterations,repartition):
    """
        Prend en params le nombre d'itérations voulues et la repartition dans les sous ensemble
        Retourne :
            - L'erreur totale moyenne (t)
            - L'erreur moyenne par essieu (t)
            - Le % d'erreur moyen total (%)
            - Le % d'erreur moyen total par essieu (%)
        Affiche :
            - Le diagramme baton des erreurs sur les poids totaux
            - Le diagrame baton des erreurs sur les poids totaux redressés
            - Le diagramme baton des erreurs par essieu
    """
    list_erreur_tot_moy = []
    list_erreur_essieu_moy = np.zeros(5)
    list_percent_erreur_moy_tot = []
    list_percent_erreur_essieu = np.zeros(5)
    list_erreurs_tot = []
    list_erreurs_tot_redr = []
    list_erreur_essieu1 = []
    list_erreur_essieu2 = []
    list_erreur_essieu3 = []
    list_erreur_essieu4 = []
    list_erreur_essieu5 = []

    list_percent_tot = []
    for i in range(iterations):
        
        print("Itération n° : "+str(i+1)+"/"+str(iterations))
        se1,se2 = get_SE2(repartition)
        print("LEN SE1 : ",len(se1))
        print("LEN SE2 : ",len(se2))
        func = get_LI(se1)
        poids_estimes = get_poids(se2,func)
        scores,scores_totaux = get_erreur_essieu(se2,poids_estimes)
        erreur_tot_moy,list_percent_err_poids_tot,percent_err_moy,list_err_moy_essieux,list_percent_moy_essieux = get_metrics(scores,scores_totaux,se2)
        for a,j in enumerate(poids_estimes):
            list_erreurs_tot.append(np.sum(j)-np.sum(se2[a].weights))
            print("ERREUR : ",np.sum(j)-np.sum(se2[a].weights))
            if(abs(np.sum(j)-np.sum(se2[a].weights) > 20)):
                print(se2[a].speed)
                plt.figure()
                plt.plot(se2[a].signals)
                plt.show()
            list_erreurs_tot_redr.append(abs(np.sum(j)-np.sum(se2[a].weights)))

            list_percent_tot.append(100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            #print(1-100*(list_erreurs_tot[a]/np.sum(se2[a].weights)))
            for a,j in enumerate(poids_estimes.T[0]):
                list_erreur_essieu1.append(j-se2[a].weights[0])
            for a,j in enumerate(poids_estimes.T[1]):
                list_erreur_essieu2.append(j-se2[a].weights[1])
            for a,j in enumerate(poids_estimes.T[2]):
                list_erreur_essieu3.append(j-se2[a].weights[2])
            for a,j in enumerate(poids_estimes.T[3]):
                list_erreur_essieu4.append(j-se2[a].weights[3])
            for a,j in enumerate(poids_estimes.T[4]):
                list_erreur_essieu5.append(j-se2[a].weights[4])
        #print("\n\n\n\nMetrics sur les poids totaux : \n\n")
        #print("Liste des erreurs totales (t) : ",scores_totaux)
        #print("\nErreur totale moyenne sur l'ensemble des camions de test (t) : ",erreur_tot_moy)
        list_erreur_tot_moy.append(erreur_tot_moy)
        #print("\nListe des % d'erreur sur le poids total de chaque camion de test (%)",list_percent_err_poids_tot)
        #print("\n% d'erreur moyen sur les poids totaux des camions de test (%)",percent_err_moy)
        list_percent_erreur_moy_tot.append(percent_err_moy)
        #print("\n\nMetrics sur les poids par essieu : \n\n")
        #print("Scores par essieu (t) \n", scores)
        #print("\nListe des erreurs moyennes par essieu (t) : ",list_err_moy_essieux)
        #list_erreur_essieu_moy = np.add(list_erreur_essieu_moy,list_err_moy_essieux)
        #print("\nListe des % d'erreur moyen par essieu (%) : ",list_percent_moy_essieux)
        #list_percent_erreur_essieu = np.add(list_percent_erreur_essieu,list_percent_moy_essieux)
        
        #erreur_tot_moy = np.sum(np.array(list_erreur_tot_moy)/len(list_erreur_tot_moy))
        #erreur_essieu_moy =list_erreur_essieu_moy/len(list_erreur_essieu_moy)
        #percent_err_tot_moy = np.sum(list_percent_erreur_moy_tot)/len(list_percent_erreur_moy_tot)
        #percent_erreur_essieux = list_percent_erreur_essieu/len(list_percent_erreur_essieu)
    list_erreurs_tot=np.array(list_erreurs_tot)
    list_erreurs_tot_redr=np.array(list_erreurs_tot_redr)
    list_erreur_essieu1=np.array(list_erreur_essieu1)
    list_erreur_essieu2=np.array(list_erreur_essieu2)
    list_erreur_essieu3=np.array(list_erreur_essieu3)
    list_erreur_essieu4=np.array(list_erreur_essieu4)
    list_erreur_essieu5=np.array(list_erreur_essieu5)

    
    
    return list_erreurs_tot,list_erreurs_tot_redr,list_percent_tot,list_erreur_essieu1,list_erreur_essieu2,list_erreur_essieu3,list_erreur_essieu4,list_erreur_essieu5
let2,letr2,lpt2,lee12,lee22,lee32,lee42,lee52= get_stats2(2,20)
# Out:
# Itération n° : 1/2
# LEN SE1 :  20
# LEN SE2 :  5
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# ERREUR :  -0.25225083626994405
# ERREUR :  -5.455984089997131
# ERREUR :  -3.9643916320264694
# ERREUR :  0.5383445569588758
# ERREUR :  2.806655401112401
# Itération n° : 2/2
# LEN SE1 :  20
# LEN SE2 :  5
# ********** Working on LI... **********
# ********** Working on weights... **********
# ********** Working on errors... **********
# **********  Working on metrics... **********
# ERREUR :  -0.4480917353631
# ERREUR :  1.2560235658569496
# ERREUR :  -0.8105492950575339
# ERREUR :  4.829726009227073
# ERREUR :  -0.5758783060933652

# %%
import seaborn as sns
# %matplotlib inline

sns.distplot(let2, hist=True, rug=True);
plt.title("Erreurs sur les poids totaux (t)")
plt.figure()
sns.distplot(lee12, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 1 (t)")
plt.figure()
sns.distplot(lee22, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 2 (t)")
plt.figure()
sns.distplot(lee32, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 3 (t)")
plt.figure()
sns.distplot(lee42, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 4 (t)")
plt.figure()
sns.distplot(lee52, hist=True, rug=True);
plt.title("Erreurs sur les poids Essieu 5 (t)")
# Out:
# Text(0.5, 1.0, 'Erreurs sur les poids Essieu 5 (t)')

# %%
from scipy import signal

calibration_trucks,traffic_trucks = load_senlis_modified(selected=6) #[3,4,6,7]
trucks = [truck for truck in calibration_trucks if(len(truck.weights) == len(truck.peaks))]
trucks_t = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks) and truck.speed>23.9)]

list_speeds = []
list_meters= []
list_infl = []
list_times = []
list_infl_calib = []
list_infl_trafic = []
list_speeds_calib = []
list_speeds_trafic = []


for i in range(len(trucks)):
    list_speeds.append(trucks[i].speed)
    list_speeds_calib.append(trucks[i].speed)

    meters= trucks[i].speed*trucks[i].time
    list_meters.append(signal.resample(meters,701))
    infl = calibration_mt(trucks[i:i+1],l2_reg={'strength': 1e3, 'cutoff': 0.01},tv_reg={'strength': 1e3, 'cutoff': 0.95})
    list_infl.append(infl)
    list_infl_calib.append(infl)    
    list_times.append(signal.resample(trucks[i].time,701))


    
list_infl = np.array(list_infl)
list_infl_calib = np.array(list_infl_calib)
list_infl_trafic = np.array(list_infl_trafic)

list_speeds = np.array(list_speeds)
list_infl_calib = np.array(list_infl_calib)
list_speeds_calib = np.array(list_speeds_calib)
list_speeds_trafic = np.array(list_speeds_trafic)

list_meters = np.array(list_meters)
list_times = np.array(list_times)


print(list_speeds.shape)
print(list_meters.shape)
print(list_infl.shape)
print(list_times.shape)

from scipy.interpolate import interp1d

func   = interp1d(list_speeds, list_infl, fill_value="extrapolate",axis=0)#permet à partir de meters et infuence de trouver une approximation de influence = f(meters)
# Out:
# (11,)
# (11, 701)
# (11, 701)
# (11, 701)

# %%
traffic_trucks = [truck for truck in traffic_trucks if(len(truck.weights) == len(truck.peaks))]
for truck in traffic_trucks:
    print(truck.speed)
# Out:
# 23.630778718660313
# 24.0
# 23.99998055697778
# 24.380962370591252
# 23.27274641740299
# 25.18025490149026
# 22.26084595150235
# 23.63081643339881
# 22.260903648897617
# 23.630750086870428
# 23.272717998418727
# 24.000047940170667
# 24.00002912772182
# 24.380892824572964

# %%
# camion anormale car vitesse jamais atteinte précédemment (2nd vitesse la plus élevée = 24.4 m/s)
truck_anormal = traffic_trucks[5]

print(truck_anormal.speed)
plt.figure()
plt.plot(truck_anormal.signals)
plt.show()
reconstructed, rescaled = reconstruction_peaks(truck_anormal, func(truck_anormal.speed),truck_anormal.peaks)
meters = truck_anormal.speed*truck_anormal.time
plt.figure()
plt.plot(func(truck_anormal.speed))
plt.show()
plt.figure()
plt.plot(meters[:len(reconstructed)], reconstructed[:len(meters)], linewidth=2, label='Recon.')
plt.plot(meters[:len(truck_anormal.signals.T)], truck_anormal.signals.T[:len(meters)], label='Observed', alpha=0.7)
plt.legend()
plt.show()
# Out:
# 25.18025490149026
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
